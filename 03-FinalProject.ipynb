# %% [markdown]
# # Clothing Consumption and Clothing Disposal Among College Students
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [X] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# - Noor Bouzelfane: Analysis, Video Slides
# - Rylee Correa:  Background, Video Production
# - Sarena Pham:  Abstract, Video Slides
# - Rachel Handran:  Discussion, Conclusion
# - Daniel Mulford:  Analysis, Video Script

# %% [markdown]
# ## Research Question

# %% [markdown]
# Among college students, are disposal reasons and disposal methods of clothes related to how often they are purchased and whether they are new or secondhand?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Fast fashion is a clothing production model where clothing is produced quickly and cheaply, with rapid turnover due to changing trends and high-volume manufacturing. This method of production has significantly altered the fashion industry, influencing how trends spread and how consumers purchase clothing, particularly over the past two decades.
#
# On one hand, this model has been praised for making clothing more affordable to consumers who may not otherwise be able to purchase expensive or high-quality garments. Lower prices allow a wider range of people to participate in fashion trends and access a greater variety of clothing styles. However, this accessibility also raises concerns about textile lifespan and sustainability. Garments are increasingly manufactured in ways that shorten their usable life, contributing to higher rates of waste, pollution, and resource consumption.
# Prior research suggests that fast fashion production practices may directly reduce textile lifespan. According to the Sustainability Directory, fast fashion brands more often use inexpensive synthetic fibers and lower-quality materials in their clothing. These fabrics tend to degrade more quickly with repeated wear and washing, causing garments to lose structural integrity after a few uses.<a name="#ref1"></a>[<sup>1</sup>](#note1) While lower production costs make clothing more accessible, this tradeoff between affordability and durability may encourage consumers to replace garments more frequently, increasing the total volume of clothing discarded.
#
# Consumer behavior also plays a major role in this cycle. The rapid release of new styles encourages consumers to replace clothing that is still wearable but no longer “in style.” According to the United States Environmental Protection Agency, the total mass of textile waste generated each year has increased roughly tenfold since 1960. <a name="#ref4"></a>[<sup>4</sup>](#note4) This increase suggests that changes in consumption patterns, rather than population growth alone, are a major contributor to textile waste.
#
# International organizations report similar trends. The Geneva Environment Network estimates that approximately 85% of textiles are discarded each year, with the majority ending up in landfills or incinerators rather than being recycled.<a name="#ref2"></a>[<sup>2</sup>](#note2) Their findings indicate that the modern fashion industry prioritizes high production volume and low costs, but does not maintain clothing within long-term circulation systems such as repair, reuse, or recycling. As a result, garments often move quickly from production to disposal.
#
# However, researchers have also identified challenges in accurately measuring the environmental impact of fast fashion. A Vox investigation by Alden Wicker highlights that many widely cited statistics about clothing waste originate from limited regional studies or outdated data.<a name="#ref3"></a>[<sup>3</sup>](#note3) While there is strong consensus that fast fashion contributes to overproduction and environmental strain, the exact scale of the problem remains difficult to quantify. Estimates of garment lifespan and disposal rates vary significantly between studies, and many rely on aggregated industry data rather than direct consumer behavior measurements. This uncertainty highlights an important limitation in existing research, where much of the available data focuses on large-scale industry production rather than the everyday clothing habits of individual consumers.
#
# Understanding how people actually purchase, wear, and dispose of clothing is essential for evaluating how fast fashion operates at the consumer level.
# The lack of reliable consumer-level data surrounding the garment industry led us to examine clothing use and disposal practices within a specific population, in this case college students. College students represent a particularly relevant demographic because they are frequent consumers of fast fashion brands and often face financial constraints that influence purchasing decisions. By analyzing self-reported behaviors from this population, this study aims to provide more concrete insight into how clothing is purchased, used, and ultimately discarded. Our sources therefore provide a foundation for investigating how broader fast fashion trends may manifest in the everyday consumption patterns of college students.
#
# 1. <a name="note1"></a> [^](#ref1) Sustainability Directory, “How Does Fast Fashion Influence Textile Lifespan?”
# https://fashion.sustainability-directory.com/question/how-does-fast-fashion-influence-textile-lifespan/
# 1. <a name="note2"></a> [^](#ref2) Geneva Environment Network, “Sustainable Fashion”
# https://www.genevaenvironmentnetwork.org/resources/updates/sustainable-fashion/
# 1. <a name="note3"></a> [^](#ref3) Wicker, A. (2020). “Fashion Has a Misinformation Problem. That’s Bad for the Environment.” Vox.
# https://www.vox.com/the-goods/2020/1/27/21080107/fashion-environment-facts-statistics-impact
# 1. <a name="note4"></a> [^](#ref4) United States Environmental Protection Agency. 2025. "Textiles: Material-Specific Data". https://www.epa.gov/facts-and-figures-about-materials-waste-and-recycling/textiles-material-specific-data

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict a strong correlation between shoppers who mostly buy secondhand and donation as a disposal method, and a correlation between higher frequency shoppers and increased likelihood of throwing away clothes due to damage.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset Name: Clothing Purchasing Behavior Survey
#   - Link to the dataset: https://docs.google.com/spreadsheets/d/1nvZ9Xgglo6VaNepIcNP9U200YDhCxrai-49RlTinzPg/edit?usp=sharing
#   - Dataset inquiries: Email us at rhandran@ucsd.edu
#   - Number of observations: 289
#   - Number of variables: Six
#   - Description of the variables most relevant to this project: Shopper Type (New vs. Secondhand), Purchase Frequency, Average Price, Disposal Method, Disposal Reason, Area of Study
#   - Descriptions of any shortcomings this dataset has with respect to the project Student fields of studies may not be representative of college students at large
#
# #### Survey
# Note: All questions are single-select radio buttons except for the final question with is a checkbox select up to 2.
#
# Title: Clothing Purchasing Behavior Survey
# What is your primary area of study?
# - Arts & Humanities
# - Biological Sciences
# - Engineering
# - Health Sciences
# - Social Sciences
# - Physical Sciences
# - Other:
#
# 1. In the past year, was the clothing you bought:
#
# - Almost always new
# - Mostly new, some secondhand
# - About equal new and secondhand
# - Mostly secondhand, some new
# - Almost always secondhand
#
# 2. In the past year, how often did you buy clothing (including purchases, gifts, and secondhand)?
# - About once per week or more
# - About once per month
# - Every few months
# - About once a year
# - Every few years
#
# 3. Average price: How much do you typically spend on a single shirt/top? ($)
# - 0-5
# - 5-15
# - 15-35
# - 35-75
# - 75+
#
# 4. Disposal method: When getting rid of clothes, what do you usually do?
# - Donate (Thrift store, handing down)
# - Sell (eBay, yard sale)
# - Throw away (Trash/Landfill)
# - Textile recycling program
# - Other:
#
# 5. When getting rid of clothes, what is the primary reason for doing so? (Select up to 2)
# - Torn/Broken
# - Doesn't fit anymore
# - Don't like it anymore
# - Selling for money
# - Freeing up space
# - Other:

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1K8x4C1VlC196nZJO-l2J5TNqj7og-dja', 'filename':'Clothing Purchasing Behavior.csv'},
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Successfully downloaded: Clothing Purchasing Behavior.csv

# %% [markdown]
# ### Clothing Purchasing Behavior Survey
#
# Shopper Type is what we hypothesize is the predictor in our data, and it is a categorical variable. It describes the average condition of the clothing respondents bought in the past year, as they report it. It is an ordinal variable with five mutually exclusive levels: “Almost always new”, “Mostly new, some secondhand”, “About equal new and secondhand”,  “Mostly secondhand, some new”, and “Almost always secondhand”.
#
# The four variables we hypothesize to be predicted by clothing purchase type are Purchase Frequency, Average Price, Disposal Method, and Disposal Reason. Purchase Frequency is a categorical variable that describes what respondents think is their average frequency of clothing purchases in the past year. It is an ordinal variable with five mutually exclusive levels: “About once per week or more”, “About once per month”, “Every few months”, “About once a year”, and “Every few years”. Average Price is a numerical variable that describes the range in dollars that respondents think they typically spend on a single shirt/top. It is an ordinal variable with five mutually exclusive levels: “0-5”, “5-15”, “15-35”, “35-75”, and “75+”. Disposal Method is a categorical variable that describes the method by which respondents typically dispose of their clothes, according to them. It is a nominal variable with five mutually exclusive categories: “Donate”, “Sell”, “Throw away”, “Textile recycling program”, and “Other (fill in)”. Disposal Reason is a categorical variable that describes what respondents think are their primary reasons for disposing of their clothes. It is a nominal variable with six categories, with up to two optionally co-occurring; the categories are “Torn/Broken”, “Doesn’t fit anymore”, “Don’t like it anymore”, “Selling for money”, “Freeing up space”, “Other (fill in)”.
#
# Area of Study is a variable that we anticipate affecting outcomes, despite not hypothesizing it as the predictor of outcomes. It is a categorical variable that describes the primary field of study of college students responding to our survey. It is a nominal variable with seven mutually exclusive categories: “Arts & Humanities”, “Biological Sciences”, “Engineering”, “Health Sciences”, “Social Sciences”, “Physical Sciences”, and “Other (fill in)”. One concern with our survey dataset is the disproportionate amount of engineering student respondents, since most college students are not necessarily engineering majors. Our sample is somewhat biased towards the characteristics of our team because of how we are sourcing survey responses; for example, we got many responses from the COGS 108 class. An additional concern with the dataset is that the Disposal Method variable may be unrepresentative of our population due to social desirability bias; although our survey is anonymous and we aimed to use neutral language, respondents may actually throw away clothes more often than they report.

# %% [markdown]
# ### Tidying

# %%
import pandas as pd
df = pd.read_csv('data/00-raw/Clothing Purchasing Behavior.csv')
df.columns = [
    'timestamp',
    'consent',
    'major',
    'new_vs_secondhand',
    'purchase_freq',
    'avg_price',
    'disposal_method',
    'disposal_reason'
]
# Give common disposal reasons their own columns; collect singletons in a column called 'other'
df_tidy = df.copy()
disposal_col_names = {
    "Doesn't fit anymore": "disposal_reason_doesnt_fit",
    "Don't like it anymore": "disposal_reason_dont_like",
    "Freeing up space": "disposal_reason_space",
    "Torn/Broken": "disposal_reason_torn",
    "Selling for money": "disposal_reason_money"
}
for reason, new_col in disposal_col_names.items():
    df_tidy[new_col] = df_tidy['disposal_reason'].str.contains(reason).astype(bool)
def is_other(response: str) -> bool:
    reasons = response.split(', ')
    for reason in reasons:
        if reason not in disposal_col_names:
            return True
    return False

df_tidy['disposal_reason_other'] = df_tidy['disposal_reason'].apply(is_other)
df_tidy = df_tidy.drop(columns=['disposal_reason'])

df_clean = df_tidy.copy()
# Major is the only column with missing values. Since we can make valid inferences without it, we will simply fill them in.
df_clean['major'] = df_clean['major'].fillna('Unknown')

# Standardize the text in the major column
df_clean['major'] = df_clean['major'].str.strip().str.lower()

# Respondent 3 had trouble selecting the survey options, so their response is invalid. Otherwise, everything looks OK.
df_clean = df_clean.drop(index=3)

# Drop nonconsenting participants.
df_clean = df_clean[df_clean['consent'] == "Yes"]
df_clean = df_clean.drop(columns=['consent'])

reason_cols = [
    "disposal_reason_doesnt_fit",
    "disposal_reason_dont_like",
    "disposal_reason_space",
    "disposal_reason_torn",
    "disposal_reason_money",
    "disposal_reason_other"
]
df_long = df_clean.melt(
    id_vars=["disposal_method"],
    value_vars=reason_cols,
    var_name="disposal_reason",
    value_name="selected"
)
df_long = df_long[df_long["selected"]]
reason_label_map = {
    "disposal_reason_doesnt_fit": "Doesn't fit",
    "disposal_reason_dont_like": "Don't like it",
    "disposal_reason_space": "Freeing space",
    "disposal_reason_torn": "Torn/Broken",
    "disposal_reason_money": "Selling for money",
    "disposal_reason_other": "Other"
}
df_long["disposal_reason"] = df_long["disposal_reason"].map(reason_label_map)

# map relevant "other" responses to the appropriate categories in disposal_method_clean
def simplify_method(method):
    method = str(method).lower()

    if "donate" in method or "thrift" in method or "hand down" in method:
        return "Donate"
    elif "sell" in method or "ebay" in method or "yard sale" in method:
        return "Sell"
    elif ("recycl" in method or "cut" in method or "scrap" in method or "patch" in method or "sewing" in method or "rag" in method or "cleaning" in method or "repurpose" in method):
        return "Recycle"
    elif "trash" in method or "throw" in method or "landfill" in method:
        return "Throw Away"
    elif "keep" in method or "closet" in method:
        return "Keep"
    else:
        return "Other"
df_long["disposal_method_clean"] = df_long["disposal_method"].apply(simplify_method)

# add disposal_method_clean to df_clean as well 
df_clean["disposal_method_clean"] = df_clean["disposal_method"].apply(simplify_method)
# drop the original disposal_method column since we have the cleaned version now
df_clean = df_clean.drop(columns=['disposal_method'])

df_clean.to_csv('data/02-processed/survey_clean2.csv', index=False)
df_clean.head()
# Out:
#            timestamp    major               new_vs_secondhand  \
# 0  2/5/2026 15:18:59  unknown  About equal new and secondhand
# 1  2/5/2026 15:20:07  unknown     Mostly new, some secondhand
# 2  2/5/2026 15:21:04  unknown     Mostly new, some secondhand
# 4  2/5/2026 17:04:04  unknown     Mostly new, some secondhand
# 5  2/5/2026 19:34:45  unknown               Almost always new
#
#           purchase_freq avg_price  disposal_reason_doesnt_fit  \
# 0  About once per month      5-15                        True
# 1  About once per month     15-35                       False
# 2     About once a year      5-15                       False
# 4      Every few months      5-15                        True
# 5     About once a year      5-15                        True
#
#    disposal_reason_dont_like  disposal_reason_space  disposal_reason_torn  \
# 0                      False                  False                 False
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# We will explore the following aspects of our data:
# - Area of Study
# - Shopper Type vs. Disposal Method
# - Purchase Frequency vs. Disposal Method
# - Shopper Type vs. Disposal Reason
# - Purchase Frequency vs. Disposal Reason
# - Shopper Type vs. Purchase Frequency

# %%
# importing libraries for analysis and visualization
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
import seaborn as sns
from matplotlib.ticker import PercentFormatter

# ignore warnings about upcoming library changes
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)



# loading the cleaned survey data with 289 responses
df = pd.read_csv('data/02-processed/survey_clean2.csv')

# %% [markdown]
# #### Major Proportions: Does our survey sample reflect the general UCSD population by major?
#
# Our goal with this EDA is to explore whether our sample is representative of the general UCSD population in terms of major, in the case that major may be  confounding varibale.
#
# We considered that certain majors may be more likely to shop secondhand, such as environmental studies or fashion. However, we want to first see how "good" our data matches UCSD's distribution.
#
# We will do this with a Chi-Square Goodness of Fit Test.
#
# - Null Hypothesis: The survey sample proportion by major does NOT significantly differ from the expected proportions (from the UCSD degrees-conferred dataset). Hidden assumption: The UCSD degrees-conferred dataset is approximately equal to the number of people in a major
# - Alternate Hypothesis: The survey sample proportion by major DOES significantly differ from the expected proportions

# %%
# Keyword-Based Classifier Function: Maps Major keywords to 7 Categories
# This code block was generated with GPT-4 and edited to reflect common major keywords of UCSD students
def categorize_major(input_major):
    
    if any(word in input_major for word in [
        'literature', 'history', 'philosophy', 'art', 'music',
        'theatre', 'visual', 'foreign language', 'linguistics',
        'humanities', 'arts', 'theater', 'dance', 'english'
    ]):
        return 'humanities' # Arts & Humanities
    
    elif any(word in input_major for word in [
        'bio', 'neuro', 'chem', 'biological',
        'human biology', 'life science'
    ]):
        return 'bio' # Biological Sciences
   
    elif any(word in input_major for word in [
        'health', 'public health'
    ]):
        return 'health' # Health Sciences
    
    elif any(word in input_major for word in [
        'engineering', 'computer', 'electrical',
        'mechanical', 'structural', 'nano', 'aerospace', 'civil', 'industrial'
    ]):
        return 'engineering' # Engineering
    
    elif any(word in input_major for word in [
        'physical', 'physics', 'math', 'mathematics', 'statistics',
        'astronomy', 'physical science'
    ]):
        return 'physical' # Physical Sciences
    
    elif any(word in input_major for word in [
        'social', 'cognitive', 'psychology', 'econ', 'economics', 'sociology',
        'political', 'international', 'anthropology',
        'communication', 'business', 'finance'
    ]):
        return 'social' # Social Sciences
    
    else:
        return 'other'

# %%
# Apply categorization method to df
df['category'] = df['major'].apply(categorize_major)

# %%
observed_counts = df['category'].value_counts()

# Reorder/force in case one category doesnt appear (generated by GPT-4)
categories = [
    'humanities',
    'bio',
    'health',
    'engineering',
    'physical',
    'social',
    'other'
]

observed_counts = (
    df['category']
    .value_counts()
    .reindex(categories, fill_value=0)
)

print(observed_counts)
# Out:
# category
# humanities      16
# bio             25
# health          15
# engineering    100
# physical        23
# social          81
# other           29
# Name: count, dtype: int64

# %% [markdown]
# Now, we must extract the actual UCSD data.
#
# Transcribe the data from this table: J. Disciplinary Areas of DEGREES CONFERRED
#
# For each of the following discipline areas, provide the percentage of diplomas/certificates, associate, and bachelor’s degrees awarded. To
# determine the percentage, use majors, not headcount (e.g., students with one degree but a double major will be represented twice).
# Calculate the percentage from your institution’s IPEDS Completions by using the sum of 1st and 2nd majors for each CIP code as the
# numerator and the sum of the Grand Total by 1st Majors and the Grand Total by 2nd major as the denominator. If you prefer, you can
# compute the percentages using 1st majors only.
#
# pdf: https://ir.ucsd.edu/stats/undergrad/J3.pdf

# %%
ucsd_data = [
    ("Natural resources and conservation", 0.9),
    ("Architecture", 1.2),
    ("Area, ethnic, and gender studies", 0.3),
    ("Communication/journalism", 2.4),
    ("Computer and information sciences", 7.0),
    ("Education", 0.6),
    ("Engineering", 11.6),
    ("Foreign languages, literatures, and linguistics", 0.6),
    ("Family and consumer sciences", 0.6),
    ("English", 0.8),
    ("Liberal arts/general studies", 0.1),
    ("Biological/life sciences", 20.8),
    ("Mathematics and statistics", 3.8),
    ("Interdisciplinary studies", 15.4),
    ("Philosophy and religious studies", 0.2),
    ("Physical sciences", 3.0),
    ("Psychology", 8.7),
    ("Social sciences", 9.2),
    ("Visual and performing arts", 3.3),
    ("Health professions and related programs", 3.5),
    ("Business/marketing", 5.2),
    ("History", 0.8)
]

# %%
# Create UCSD data df
ucsd_df = pd.DataFrame(ucsd_data, columns=["degree", "percentage"])
# Clean
ucsd_df['degree_clean'] = ucsd_df['degree'].str.lower().str.strip()
# Apply categorization method
ucsd_df['category'] = ucsd_df['degree_clean'].apply(categorize_major)
ucsd_df
# Out:
#                                              degree  percentage  \
# 0                Natural resources and conservation         0.9
# 1                                      Architecture         1.2
# 2                  Area, ethnic, and gender studies         0.3
# 3                          Communication/journalism         2.4
# 4                 Computer and information sciences         7.0
# 5                                         Education         0.6
# 6                                       Engineering        11.6
# 7   Foreign languages, literatures, and linguistics         0.6
# 8                      Family and consumer sciences         0.6
# 9                                           English         0.8
# 10                     Liberal arts/general studies         0.1
# 11                         Biological/life sciences        20.8
# 12                       Mathematics and statistics         3.8
# 13                        Interdisciplinary studies        15.4
# ...

# %%
# Aggregate UCSD percentages by category
expected_percent = (ucsd_df.groupby('category')['percentage'].sum())

# reorder to match
expected_percent = expected_percent.reindex(categories, fill_value=0)
#expected_percent

# %%
# Convert percentages to proportions
expected_prop = expected_percent/100
# Expected counts
n = len(df) # number of survey respondents
print("Current number of survey respondents: " + str(n))
expected_counts = expected_prop * n
print("Expected counts")
print(expected_counts)

print("Observed counts")
print(observed_counts)
# Out:
# Current number of survey respondents: 289
# Expected counts
# category
# humanities     16.762
# bio            60.112
# health         10.115
# engineering    53.754
# physical       19.652
# social         73.695
# other          54.910
# Name: percentage, dtype: float64
# Observed counts
# category
# humanities      16
# bio             25
# health          15
# engineering    100
# physical        23
# social          81
# other           29
# Name: count, dtype: int64

# %%
# Compute Chi Square Contributions Manually
chi_contributions = (observed_counts - expected_counts)**2 / expected_counts
print("Chi Contributions per Category")
print(chi_contributions)
chi_square = chi_contributions.sum()
print("Manually computed Chi Square Value: " +str(chi_square))
# Degrees of Freedom
df_chi = len(categories) - 1 # we already know this is 7 categories -1 = 6
print("Degrees of Freedom: " + str(df_chi))
# Out:
# Chi Contributions per Category
# category
# humanities      0.034640
# bio            20.509258
# health          2.359192
# engineering    39.786667
# physical        0.570380
# social          0.724106
# other          12.225972
# dtype: float64
# Manually computed Chi Square Value: 76.21021592881625
# Degrees of Freedom: 6

# %%
# Run the Scipy Chi Square Test
from scipy.stats import chisquare

assert(observed_counts.sum() == expected_counts.sum()) # Ensure counts equal before running test

chi_statistic, p_value = chisquare(f_obs=observed_counts, f_exp=expected_counts)
print("Scipy computed Chi-square statistic: ", chi_statistic) # This should match the value from manual findings!
print("p-value: ", p_value)
# Out:
# Scipy computed Chi-square statistic:  76.21021592881625
# p-value:  2.1621348060485112e-14

# %%
# Bar Chart (generated code with GPT-4)
pretty_labels = {
    'humanities': 'Arts & Humanities',
    'bio': 'Biological Sciences',
    'health': 'Health Sciences',
    'engineering': 'Engineering',
    'physical': 'Physical Sciences',
    'social': 'Social Sciences',
    'other': 'Other'
}

# convert old labels into pretty labels
display_labels = [pretty_labels[cat] for cat in categories] 

x = np.arange(len(categories))

plt.figure()
plt.bar(x - 0.2, observed_counts, width=0.4, label="Observed")
plt.bar(x + 0.2, expected_counts, width=0.4,label="Expected")
plt.legend()

plt.xticks(x, display_labels, rotation=45)
plt.ylabel("Count")
plt.title("Observed vs Expected Major Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the bar chart, we can see that some major categories are overrepresented in our survey sample. Engineering is highly oversampled, while Biological Sciences are greatly undersampled. This is likely due to the survey distribution through methods like UCSD canvas, discord, and COGS108 announcements, where many students are more likely to be Engineering majors.
#
# Overall, this EDA helps to assess if our survey was representative of the general student population in terms of major.  This informs us if major-sampling bias may later influence our analysis of clothing behavior responses. However, more in-depth analysis is needed to determine if major is a true confounding variable for clothing purchase and disposal habits.

# %% [markdown]
# #### Shopper Type vs. Disposal Method

# %% [markdown]
# Let's investigate our hypothesis that shoppers who buy new or more likely to throw away unwanted clothes, while shoppers who buy secondhand are more likely to donate unwanted clothes.

# %% [markdown]
# Let's look at the distribution of shopper types.

# %%
# first mapping new_vs_secondhand into simpler categories for better visualization
new_vs_secondhand_map = {
   'Almost always new': 'New',
   'Mostly new, some secondhand': 'New',
   'About equal new and secondhand': 'Equal New & Secondhand',
   'Mostly secondhand, some new': 'Secondhand',
   'Almost always secondhand': 'Secondhand'
}

df['new_vs_secondhand'] = df['new_vs_secondhand'].map(new_vs_secondhand_map)

pie_chart = plt.pie(
    df['new_vs_secondhand'].value_counts(),
    labels=df['new_vs_secondhand'].value_counts().index
)

plt.title('Distribution of Shopper Types')
plt.axis('equal') 

plt.show()

# %% [markdown]
# Let's look at the distribution of disposal methods by shopper type.

# %%
# Group by purchase type and disposal method, count the number of responses, and reshape for plotting
plot_df = df.groupby(['new_vs_secondhand', 'disposal_method_clean']).size().unstack('disposal_method_clean').fillna(0)

# Normalize by shopper type to get proportion of shopper groups that use each disposal method
sub_df = plot_df.div(plot_df.sum(axis=1), axis=0)

# Generate plot
ax = sub_df.plot(kind='bar', stacked=True, rot=0,
                      title='Disposal Methods by Shopper Type')

# Customize plot labels
ax.legend(title='Disposal Method', loc='center left', bbox_to_anchor=(1.0, 0.5))
ax.set_ylabel("Proportion within group")
ax.set_xlabel("Shopper Type")

plt.show()

# %% [markdown]
# The stacked barplot displays the proportion of disposal methods within each group of shoppers. It shows that the proportion of secondhand shoppers who donate their clothes is less than that of new shoppers. This contradicts our hypothesis that there is a higher proportion of donaters among secondhand shoppers compared to new shoppers. However, the plot does show a higher proportion of throwing away clothes among new shoppers compared to secondhand shoppers. Secondhand shoppers have the highest proportion of recyclers and sellers of unwanted clothes. As for shoppers who buy equal new and secondhand, they are the group with the highest proportion of donaters.
#
# Now, let's see if the relationship between shopper type and disposal method is statistically significant using a Chi-Square test. This is the appropriate metric because shopper type and disposal method are categorical variables, and disposal method is  nominal rather than ordinal.

# %%
# Contingency table of raw counts for purchase type vs disposal method
contingency_table = pd.crosstab(df['new_vs_secondhand'], df['disposal_method_clean'])

# Run the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
# Out:
# Chi-Square Statistic: 16.74643208081619
# P-value: 0.08016649561621209
# Degrees of Freedom: 10

# %% [markdown]
# The p-value is 0.08, so, at the 5% significance level, the relationship between shopper type and disposal method is not statistically signifcant.

# %% [markdown]
# #### Purchase Frequency vs. Disposal Method

# %% [markdown]
# Let's investigate our hypothesis that higher purchase frequency means higher likelihood of throwing away clothing.

# %%
# order purchase frequency for better visualization
freq_order = [
    'Every few years',
    'About once a year',
    'Every few months',
    'About once per month',
    'About once per week or more'
]

# convert purchase_freq to categorical with the specified order
df_clean['purchase_freq'] = pd.Categorical(
    df_clean['purchase_freq'], 
    categories=freq_order, 
    ordered=True
)

# Group by purchase type and disposal method, count the number of responses, and reshape for plotting
plot_df = df_clean.groupby(['purchase_freq', 'disposal_method_clean']).size().unstack('disposal_method_clean').fillna(0)

# Normalize by shopper type to get proportion of shopper groups that use each disposal method
sub_df = plot_df.div(plot_df.sum(axis=1), axis=0)

# Generate plot
ax = sub_df.plot(kind='barh', 
                 stacked=True, 
                 rot=0,
                 cmap='Set3',
                 title='Disposal Methods by Purchase Frequency')

# Customize plot labels
ax.legend(title='Disposal Method', loc='center left', bbox_to_anchor=(1.0, 0.5))
ax.set_xlabel("Proportion within group")
ax.set_ylabel("Purchase Frequency")

plt.show()

# %%
# Let's also look at summary statistics to confirm the trends we see in the plot
df_clean.groupby('purchase_freq')['disposal_method_clean'].describe()
# Out:
#                             count unique     top freq
# purchase_freq
# Every few years                16      4  Donate   10
# About once a year              52      5  Donate   36
# Every few months              145      6  Donate  117
# About once per month           68      4  Donate   57
# About once per week or more     8      3    Sell    4

# %% [markdown]
# The stacked barplot above shows the proportion of disposal methods represented in each purchase frequency group. The plot shows:
# - The most common disposal method for most purchase frequency groups is donation.
# - The most common disposal method for the most frequent shoppers (once per week or more) is selling.
# - The purchase frequency group most likely to throw away clothes is the least frequent shoppers.
# - The purchase frequency group least likely to throw away clothes is the most frequent shoppers.
#
# The last two points directly contradict our hypothesis that higher purchasing frequency is correlated with more throwing away of clothes.

# %% [markdown]
# Let's see if these relationships are statistically significant using a Chi-Square test. This is the appropriate metric because purchase frequency and disposal method are categorical variables, and disposal method is  nominal rather than ordinal.

# %%
# Contingency table of raw counts for purchase type vs disposal method
contingency_table = pd.crosstab(df_clean['purchase_freq'], df_clean['disposal_method_clean'])

# Run the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
# Out:
# Chi-Square Statistic: 45.20935834174459
# P-value: 0.0010335602383127643
# Degrees of Freedom: 20

# %% [markdown]
# At a significance level of 5%, there is a statistically significant relationship between purchase frequency and disposal method because the p-value is 0.001. This means we reject the null that purchase frequency and disposal method are independent.

# %% [markdown]
# Let's see the strength of the correlation between disposal method and purchase frequency using a Cramér's V test. We use this test because both categories are categorical.

# %%
# This code was generated by Gemini 3

# 1. Total number of observations (n)
n = contingency_table.sum().sum()

# 2. Find the minimum dimension of the table (rows - 1 or cols - 1)
# Cramér's V uses the 'k' factor to account for table size
min_dim = min(contingency_table.shape) - 1

# 3. Calculate Cramér's V
v = np.sqrt(chi2 / (n * min_dim))

print(f"Cramér's V: {v:.4f}")
# Out:
# Cramér's V: 0.1978

# %% [markdown]
# Given 0.10 < v < 0.30, there is a weak association between purchase frequency and disposal method.

# %% [markdown]
# #### Shopper Type vs. Disposal Reason

# %% [markdown]
# Let's investigate our hypothesis that shoppers who buy new are more likely to dispose of clothes due to damage.

# %%
# This code block was partially generated by Gemini 3

reason_cols = [
    'disposal_reason_doesnt_fit', 
    'disposal_reason_dont_like',
    'disposal_reason_space',
    'disposal_reason_torn',
    'disposal_reason_money',
    'disposal_reason_other'
]

# Melt the boolean columns
data_long = df.melt(id_vars='new_vs_secondhand', 
                  value_vars=reason_cols, 
                  var_name='disposal_reason', 
                  value_name='is_selected')

# Map reasons to more readable labels
reason_label_map = {
    'disposal_reason_doesnt_fit': "Doesn't fit",
    'disposal_reason_dont_like': "Don't like it",
    'disposal_reason_space': "Freeing up space",
    'disposal_reason_torn': "Torn/Broken",
    'disposal_reason_money': "Selling for money",
    'disposal_reason_other': "Other"
}
data_long['disposal_reason'] = data_long['disposal_reason'].map(reason_label_map)

# order purchase frequency for better visualization
freq_order = [
    'Every few years',
    'About once a year',
    'Every few months',
    'About once per month',
    'About once per week or more'
]

# convert purchase_freq to categorical with the specified order
df_clean['purchase_freq'] = pd.Categorical(
    df_clean['purchase_freq'], 
    categories=freq_order, 
    ordered=True
)

# Plotting (using the 'disposal_reason' column we just created)
ax = sns.barplot(x='disposal_reason', 
                 y='is_selected', 
                 hue='new_vs_secondhand', 
                 data=data_long, 
                 estimator=lambda x: sum(x) / len(x) * 100)

sns.despine()
ax.set_title('Frequency of Disposal Reasons by Shopper Type')
ax.set_ylabel('Percentage of Respondents in Group (%)')
ax.set_xlabel('Disposal Reason Selected (Up to 2)')

# Rotate x-axis labels if they overlap
plt.xticks(rotation=45, ha='right')

ax.legend(title='Shopper Type', loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %% [markdown]
# The grouped bar plot above shows the probability of each disposal reason being reported, grouped by shopper type. Note that the percentages don't add up to a 100 because respondents could select up to two disposal reasons. The plot shows that..
# - The shopper type most likely to dispose of clothes due to poor fit is equal new & secondhand shoppers
# - The shopper type most likely to dispose of clothes to free up space is secondhand shoppers.
# - The shopper type most likely to dispose of clothes due to damage is new shoppers.

# %% [markdown]
# Let's see if these relationships are statistically significant with a Chi-Square test for multiple responses. This is the appropriate metric because while both variables are categorical, a standard Chi-Square test could not account for the fact that respondents can select up to two disposal reasons. So, we run six separate Chi-Square tests and adjust the significant p-value accordingly.

# %%
# This code was generated by Gemini 3

results = []
alpha = 0.05
# Adjust alpha for multiple comparisons
bonferroni_alpha = alpha / len(reason_cols)

for reason in reason_cols:
    # 1. Create the table (Shopper Type vs. This Reason)
    contingency_table = pd.crosstab(df['new_vs_secondhand'], df[reason])
    
    # 2. Run Chi-Square
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    
    results.append({
        'Disposal Reason': reason, 
        'P-Value': round(p, 4), 
        'Significant (Raw)': p < alpha,
        'Significant (Bonferroni)': p < bonferroni_alpha
    })

sig_df = pd.DataFrame(results)
print(sig_df)
# Out:
#               Disposal Reason  P-Value  Significant (Raw)  \
# 0  disposal_reason_doesnt_fit   0.3359              False
# 1   disposal_reason_dont_like   0.9930              False
# 2       disposal_reason_space   0.1583              False
# 3        disposal_reason_torn   0.2379              False
# 4       disposal_reason_money   0.1805              False
# 5       disposal_reason_other   0.3687              False
#
#    Significant (Bonferroni)
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False

# %% [markdown]
# The relationship between disposal reason and shopper type is not statistically significant as the lowest p-value across disposal reasons is still too large, at 0.16. We fail to reject the null that there is no relationship between disposal reason and shopper type.

# %% [markdown]
# #### Purchase Frequency vs. Disposal Reason

# %% [markdown]
# Our hypothesis suggests that fast fashion involves planned obsolescence—the clothes are made of poor quality so consumers need to re-purchase frequently. But is this really what drives purchasing frequency? Let's visualize the relationship between purchase frequency and disposal reason.

# %%
# This code block was partially generated by Gemini 3

# order purchase frequency for better visualization
freq_order = [
    'Every few years',
    'About once a year',
    'Every few months',
    'About once per month',
    'About once per week or more'
]

# convert purchase_freq to categorical with the specified order
df['purchase_freq'] = pd.Categorical(
    df['purchase_freq'], 
    categories=freq_order, 
    ordered=True
)

# Melt the boolean columns
data_long = df.melt(id_vars='purchase_freq', 
                  value_vars=reason_cols, 
                  var_name='disposal_reason', 
                  value_name='is_selected')

# Map reasons to more readable labels
reason_label_map = {
    'disposal_reason_doesnt_fit': "Doesn't fit",
    'disposal_reason_dont_like': "Don't like it",
    'disposal_reason_space': "Freeing up space",
    'disposal_reason_torn': "Torn/Broken",
    'disposal_reason_money': "Selling for money",
    'disposal_reason_other': "Other"
}
data_long['disposal_reason'] = data_long['disposal_reason'].map(reason_label_map)

# Plotting (using the 'disposal_reason' column we just created)
ax = sns.barplot(x='purchase_freq', 
                 y='is_selected', 
                 hue='disposal_reason', 
                 data=data_long, 
                 estimator=lambda x: sum(x) / len(x) * 100)

sns.despine()
ax.set_title('Disposal Reasons by Purchase Frequency')
ax.set_ylabel('Percentage of Respondents in Group (%)')
ax.set_xlabel('Purchase Frequency')

# Rotate x-axis labels if they overlap
plt.xticks(rotation=45, ha='right')

ax.legend(title='Disposal Reason Selected (Up to 2)', loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %% [markdown]
# The grouped barplot above illustrates the distribution of disposal reasons within each purchase frequency group. Important patterns emerge:
# - The group with the highest proportion of disposing due to damage is the least frequent shoppers (every few years)
# - The group with the lowest proportion of disposing due to damage is the most frequent shoppers (about once per week or more)
# - The most frequent shoppers mostly dispose of clothes due to not liking them anymore

# %% [markdown]
# These initial results contradict our assumption that shorter clothing lifespan is the reason for higher purchase frequency. This makes sense given our earlier finding that there is a correlation between lower purchasing frequency and throwing away clothes.

# %% [markdown]
# Let's see if these relationships are statistically significant with a Chi-Square test for multiple responses. Again, this is the appropriate metric because while both variables are categorical, a standard Chi-Square test could not account for the fact that respondents can select up to two disposal reasons. We also use a Cramér's V test to see the strength of association between the two categorical variables.

# %%
# This code was generated by Gemini 3

results = []
alpha = 0.05
bonferroni_alpha = alpha / len(reason_cols)

for reason in reason_cols:
    # 1. Create the table
    contingency_table = pd.crosstab(df['purchase_freq'], df[reason])
    
    # 2. Run Chi-Square
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    
    # 3. Calculate Cramér's V
    n = contingency_table.sum().sum()
    # k is the minimum of (number of rows - 1) or (number of columns - 1)
    min_dim = min(contingency_table.shape) - 1
    
    # Avoid division by zero for empty columns/rows
    if n > 0 and min_dim > 0:
        v = np.sqrt(chi2 / (n * min_dim))
    else:
        v = 0
    
    results.append({
        'Disposal Reason': reason, 
        'P-Value': round(p, 4), 
        'Cramér\'s V': round(v, 4),
        'Significant (Raw)': p < alpha,
        'Significant (Bonferroni)': p < bonferroni_alpha
    })

# Convert to DataFrame and sort by the strongest relationship
sig_df = pd.DataFrame(results).sort_values(by='Cramér\'s V', ascending=False)

print(sig_df)
# Out:
#               Disposal Reason  P-Value  Cramér's V  Significant (Raw)  \
# 3        disposal_reason_torn   0.0001      0.2917               True
# 1   disposal_reason_dont_like   0.0042      0.2298               True
# 5       disposal_reason_other   0.3419      0.1249              False
# 4       disposal_reason_money   0.4540      0.1125              False
# 2       disposal_reason_space   0.5741      0.1002              False
# 0  disposal_reason_doesnt_fit   0.7519      0.0813              False
#
#    Significant (Bonferroni)
# 3                      True
# 1                      True
# 5                     False
# 4                     False
# 2                     False
# 0                     False

# %% [markdown]
# Dislike and damage are the only disposal reasons with a statistically significant relationship to purchase frequency. Dislike has a weak association with purchase frequency, and Torn/Broken has a better, but still weak association with purchase frequency.

# %% [markdown]
# #### Shopper Type vs. Purchase Frequency

# %% [markdown]
# Our hypothesis assumes that buying new means buying more frequently because new clothes are often fast fashion and fast fashion has shorter release cycles, poorer quality, and perhaps a consumer base more interested in keeping up with trends. Let's visualize the relationship between shopper type and purchase frequency. This time, we will explore shopper type by calculating the proportion of clothes bought secondhand.

# %%
secondhand_prop_map = {
    'Almost always new': 0.0,
    'Mostly new, some secondhand': 0.25,
    'About equal new and secondhand': 0.5,
    'Mostly secondhand, some new': 0.75,
    'Almost always secondhand': 1.0
}
df_clean['secondhand_prop'] = df_clean['new_vs_secondhand'].map(secondhand_prop_map)

purchase_freq_order = [
    'Every few years',
    'About once a year',
    'Every few months',
    'About once per month',
    'About once per week',
    'About once per week or more'
]

present_purchase_freq_order = [
    freq for freq in purchase_freq_order
    if freq in df_clean['purchase_freq'].dropna().unique()
]

ax = sns.pointplot(
    data=df_clean,
    x='purchase_freq',
    y='secondhand_prop',
    order=present_purchase_freq_order,
    estimator='mean',
    errorbar=('ci', 95),
    capsize=0.1
)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.set_title('Purchase Frequency vs. Proportion Purchased Secondhand')
ax.set_xlabel('Purchase Frequency')
ax.set_ylabel('Secondhand Purchases (%)')
ax.tick_params(axis='x', rotation=20)

# %% [markdown]
# The pointplot shows that frequent shoppers have a lot of variation in the type of clothes they buy, ranging from 30 to 80% secondhand. However, the most frequent shoppers are by far the group that buys secondhand the most. This contradicts our assumption that buying new means buying more frequently.

# %% [markdown]
# Let's see if the observed pattern is statistically significant using a Kruskal-Wallis test. This is the appropriate metric since we are calculating shopper type as a numerical variable. We opt for a Kruskal-Wallis test rather than a one-way ANOVA because variance is not equal across purchase frequency groups.

# %%
# This code block was generated with Gemini 3
from scipy import stats

# 1. Prepare the data (ensure no NaNs)
df_nonparam = df_clean.dropna(subset=['purchase_freq', 'new_vs_secondhand'])

# 2. Group the data for the test
# Create a list of 'secondhand_prop' values for each 'purchase_freq' group
groups = [
    df_nonparam[df_nonparam['purchase_freq'] == freq]['new_vs_secondhand']
    for freq in present_purchase_freq_order
]

# 3. Perform the Kruskal-Wallis H-test
h_stat, p_val = stats.kruskal(*groups)

print("--- Kruskal-Wallis Result ---")
print(f"H-statistic: {h_stat:.4f}")
print(f"p-value: {p_val:.4e}")
# Out:
# --- Kruskal-Wallis Result ---
# H-statistic: 4.7492
# p-value: 3.1401e-01

# %% [markdown]
# There is no need to perform a post-hoc test because the p-value is too high. We fail to reject the null that there is no relationship between purchase frequency and proportion purchased secondhand.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > We placed a summary of our research goals at the top of the form: "We are a student team from the UCSD COGS 108 course, conducting research on clothing consumption and disposal habits of college students. Your survey responses will be aggregated in any results we publish." Checkbox: I consent to participating in this research.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > It is important to mitigate bias since this is self-reporting of consumer habits. We have phrased the survey questions carefully to be objective and simple to answer. It is possible that students will be reminded of fast fashion as a whole and try to self-report on more sustainable habits than is actually true.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  > We will not collect any PII. We will aggregate all results published or shared.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > This will be difficult to test, but we acknowledge that college students in COGS 108 may not be a representative sample of the general college student population of the world. We are in the U.S., southern California, which is not representative of colleges in other areas.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  > We will use Google forms to collect the survey data, which has built in encryption and security. We will not ask for their email or any PII.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > No, the data will be completely anonymous so we will not be able to delete data since it is not linked to a person's email.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > No, the data is not PII or sensitive.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#  > Possible sources of bias for our survey data include selection and response biases. We gave our survey to fellow COGS 108 students via Ed and in-class announcement. This was a convenient sample, but it is not necessarily representative of all UCSD students. For example, since COGS 108 students are mostly Cognitive Science and Engineering majors, we oversampled in 2 categories (Social Science and Engineering) in our survey collection. We decided to collect students' major in case it is a confounding variable in students’ clothing lifespans. Furthermore, perhaps arts majors are more likely to thrift than STEM majors. To control for these factors, we posted our survey to the r/UCSD Reddit and to other colleges’ Reddits to get a broader sample of college students. Additionally, survey responses may be subject to social desirability bias. It is less socially desirable to say you usually throw your unwanted clothes in the trash than to say you donate them. To mitigate social desirability bias, we chose more neutral language in our phrasing of questions and responses, and assured participants that their responses are anonymous. For example, instead of using the words “landfill” or “trash,” which have more negative connotations, we can use the more neutral terms “throw away” or “recycle.”
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  > 	We tried to chose the appropriate plots to visualize the data and prioritize clarity and accuracy over representations that may seem to prove our hypothesis at first glance.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > For our survey, we did not collect email addresses or names in our Google Form.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > Through GitHub commits with informative messages and detailed descriptions of the analysis process, we will ensure we can re-trace our steps in order to proofread our work and troubleshoot.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  > 	If anyone is harmed by the implications of our analysis, we will communicate with those people first and listen to their feedback. Then we will make the appropriate changes to our analysis, compensate those harmed, and counteract the effects of our mistakes by proactively facing issues of bias and harm instead of waiting for them to happen.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We can protect access to our analysis for only people who are going to use it for specific, noncommercial purposes. We can do this by keeping our data private and requiring an email request to see the results. This would be necessary to prevent unintended use, such as a fashion brand utilizing our statistics for ‘greenwashing’ purposes; this data analysis is for educational purposes and for promoting civic/environmental good, not marketing.

# %% [markdown]
# ## Discussion and Conclusion
#
# Our project investigated whether or not consumer shopping behavior, among our sample of college students, would influence disposal habits. Precisely, we predicted:
#
# We predict a strong correlation between shoppers who mostly buy secondhand and donation as a disposal method, and a correlation between higher frequency shoppers and increased likelihood of throwing away clothes due to damage.
#
# Our results indicated that these relationships are weak and not realistically predictive of behavior.
#
# 1. Students who buy secondhand clothing will be more likely to donate unwanted clothing.
#
# Initially, we phrased this as "unwanted clothing" but for our analysis, we consider any clothing that is being rid of as "unwanted" (i.e. torn, too small). In our analysis, we placed the students into 3 categories: "New", "Secondhand", and "Equal New/Secondhand" type of shoppers. We predicted that students in the "Secondhand" type would be more likely than the other 2 types to donate clothing, but our data showed no statistical significance between shopper type and disposal method. In all 3 categories, the highest proportion of disposal method was donation.
#
# 2. Higher purchase frequency correlates with higher likelihood to throw away unwanted clothing.
# We did not find a relationship between frequency and disposal method.
#
# 3. Higher purchase frequency correlates with the disposal reason being damage.
# We did not find a relationship between frequency and disposal reason.
#
# When revisiting our initial question, we realized that the most notable result was that the variables were not significantly correlated. Initially, we had made assumptions about sustainability and fast fashion as a dichotomy. We supposed that secondhand shoppers would engage in more "sustainable" methods of disposal such as reuse, donation, and reselling. We also supposed that those who buy new often were more likely to engage in "fast fashion" behaviors, which we imagined as buying new, cheap clothing often, disposing often, and disposing due to clothing being out-of-style. However, our results were contrary to our expectations and did not show any real relationships. This implies that we were likely overgeneralizing the behavior of a category of students, when in reality each person is more complex in how they consume and dispose.
#
# For our methods, we had to find a way to both gain the information about students' consumer habits, while not allowing our assumptions or biases to affect the questions. We did this by creating a survey shown above, which uses neutral language and contains no mention of words such as "fast fashion" or "sustainability", to reduce any misrepresentation of answers based on judgment. However, consumer behavior is inherently highly personal, and it was likely difficult to answer completely accurately due to the expansive/general nature of some questions.
#
# Although our hypotheses were mostly incorrect, the exploratory data analysis revealed an interesting relationship between shopper type (new vs. secondhand) and average spending per item (normalized by avg price spent on a top/shirt). Secondhand shoppers tended to spend in lower categories (0-5 and 5-15), while New shoppers tended to spend in medium categories (15-35, 35-75). Note the non-linear progression in the price increases. This indicates that the spending habits differ between the groups, while disposal habits do not. We saw this relationship and assumed this is a result of the difference between average prices in thrift stores and new shops. Though, more research must be done to examine the reason for that relationship.
#
# Altogether, our results suggest that clothing consumption and disposal behaviors are a complex relationship, far from a simple correlation between one variable to another. While we originally expected frequent shoppers to dispose due to dislike, and use landfill more often, this was not the case. These weak relationships imply that other variables, such as personal preference, storage habits, fashion trends, environmental beliefs, peer influence, and more, may play a role. The lack of strong correlations could reveal the possibility that disposal habits may be case-by-case rather than habitual. For some, a piece of clothing may play a far greater importance in life than the average consumable good. Clothing can be associated with memories, culture, and people, and it is more than the just the cloth it's made of.
#
# ### Adjustments for Future Work
# If we were to continue this work, we would like to collect more survey responses, ideally 1000+. Then, to account for potential confounding variables, we would collect gender identity, age, and major. Finally, we would like to explore deeper if these 3 variables truly change the behaviors by researching more into factors that influence shopping and consumer habits, such as trends, social media, online shopping, thrift culture, and more. There is plenty of work to be done, and our project has just scratched the surface of what can be discovered in this topic!
